# %%
import csv
from numpy import array

filename = "user_id_followers_Mexico.csv"

# %%
import pandas

# %%
colnames = ['user_id', 'count_of_followers']

# %%
data = pandas.read_csv(filename, names=colnames)

# %%
list_user_ids = data.user_id.tolist()
list_followers_count = data.count_of_followers.tolist()

# %%
print list_user_ids
# Out:
# ['user_id', '637287746', '7.11814E+17', '477686954', '67686502', '1619796360', '1529421373', '4866717149', '3073533072', '471045188', '604509261', '1260140287', '9.10726E+17', '315070591', '963274754', '2153809994', '56680780', '7.67712E+17', '4223772134', '8.86009E+17', '7.56027E+17', '212604366', '2935238777', '4116922345', '1040780562', '2283850242', '3006890556', '2472101633', '328590099', '9.10726E+17', '84364874', '7.94868E+17', '8.06004E+17', '266670642', '8.06004E+17', '190675728', '1439652692', '296562534', '3155408519', '132568157', '28219367', '2800577048', '925856569', '314611042', '100890225', '264001032', '1320000720', '8.76091E+17', '188962742', '2831069974', '15940500', '138160999', '96638533', '8.31786E+17', '289159571', '2810037368', '593866664', '2357866343', '1436601709', '8.95576E+17', '347624836', '3237251209', '2178906721', '2358081055', '104992916', '2449536145', '1041379296', '963274754', '7.4031E+17', '2550761947', '272569428', '857260747', '237443432', '376
# ...

# %%
print list_followers_count
# Out:
# ['count_of_followers', '678', '8', '167', '378', '421', '2581', '2568', '1064', '587', '493', '163', '17', '555', '530', '1821', '1042', '2727', '4943', '13', '446', '527', '436', '356', '4628', '14304', '33', '3745', '1153', '17', '722', '74', '387', '627', '387', '212', '2053', '261', '2388', '425', '397', '24847', '271', '519', '283', '67', '673', '112', '3102', '104', '548', '107', '268', '84', '1346', '25438', '405', '350', '609', '1487', '129', '264', '96', '428', '161', '53', '151', '530', '199', '22', '2236', '412', '494', '213', '1179', '9929', '287', '259', '281', '28811', '3', '117', '296', '7', '798', '111', '238', '80', '8769', '98', '76', '60', '895', '498', '49', '1', '4957', '325', '42', '42', '79', '20527', '7', '1925', '310', '1033', '107', '490', '3260', '196', '312', '7', '2419', '142', '63', '25', '1819', '236', '1033', '165', '278', '1036', '259', '223', '684', '105', '176', '13', '92', '499', '330', '89', '168', '259', '81', '354', '253', '1973', '52', '545', '
# ...

# %%
print "Mean: %d" % (np.mean(list_followers_count))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-a1352ced4774> in <module>()
# ----> 1 print "Mean: %d" % (np.mean(list_followers_count))
#
# /Applications/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in mean(a, axis, dtype, out, keepdims)
#    2887
#    2888     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2889                           out=out, **kwargs)
#    2890
#    2891
#
# /Applications/anaconda/lib/python2.7/site-packages/numpy/core/_methods.pyc in _mean(a, axis, dtype, out, keepdims)
#      68             is_float16_result = True
#      69
# ---> 70     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      71     if isinstance(ret, mu.ndarray):
#      72         ret = um.true_divide(
#
# TypeError: cannot perform reduce with flexible type

# %%
import numpy as np

# %%
np.array(list_followers_count).astype(np.int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-482a440cd669> in <module>()
# ----> 1 np.array(list_followers_count).astype(np.int)
#
# ValueError: invalid literal for int() with base 10: 'count_of_followers'

# %%
type(list_followers_count)
# Out:
# list

# %%
print "Average in 2010: %d" % (np.mean(int[](list_followers_count)))
# Out:
#   File "<ipython-input-19-5a3ecc311996>", line 1
#     print "Average in 2010: %d" % (np.mean(int[](list_followers_count)))
#                                                ^
# SyntaxError: invalid syntax

# %%
count = np.genfromtxt(filename, delimiter=",")

# %%
print count
# Out:
# [[  6.37287746e+08   6.78000000e+02]
#  [  7.11814000e+17   8.00000000e+00]
#  [  4.77686954e+08   1.67000000e+02]
#  ...,
#  [  2.81013852e+09   4.59000000e+02]
#  [  4.54571493e+08   3.79000000e+02]
#  [  7.50869000e+17   1.20270000e+04]]

# %%
count.shape
# Out:
# (50418, 2)

# %%
count.dtype
# Out:
# dtype('float64')

# %%
count[:,1].mean()
# Out:
# nan

# %%
count.mean(axis=1)
# Out:
# array([  3.18644212e+08,   3.55907000e+17,   2.38843560e+08, ...,
#          1.40506949e+09,   2.27285936e+08,   3.75434500e+17])
